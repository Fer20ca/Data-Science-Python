# %%
# !python --version
# Out:
# Python 3.12.7

# %%
# !python -m venv test2 # ya cargó

# %%
# !test2\Scripts\pip install jupyter ipykernel
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\Jose\OneDrive\Documentos\GitHub\Data-Science-Python\159857_hw1_2025_1\test2\Scripts\python.exe -m pip install --upgrade pip

# %%
# !test2\Scripts\python -m ipykernel install --user --name=test2 --display-name "Python (test)"
# Out:
# Installed kernelspec test2 in C:\Users\Jose\AppData\Roaming\jupyter\kernels\test2
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.

# %%
# !test2\Scripts\pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: C:\Users\Jose\OneDrive\Documentos\GitHub\Data-Science-Python\159857_hw1_2025_1\test2\Scripts\python.exe -m pip install --upgrade pip

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   test       C:\Users\Jose\AppData\Roaming\jupyter\kernels\test
#   test_1     C:\Users\Jose\AppData\Roaming\jupyter\kernels\test_1
#   python3    C:\Users\Jose\Nueva carpeta\share\jupyter\kernels\python3
# 0.01s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
